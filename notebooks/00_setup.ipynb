# %% [markdown]
# # Local DQ POC (POC-for-POC)
#
# This notebook validates environment and file paths.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path("..").resolve()
DATA_DIR = PROJECT_ROOT / "data" / "raw"

print("Project root:", PROJECT_ROOT)
print("Data dir:", DATA_DIR)

materials_path = DATA_DIR / "materials_master.csv"
goods_path = DATA_DIR / "goods_movements.csv"

print("Materials exists:", materials_path.exists())
print("Goods exists:", goods_path.exists())
# Out:
# Project root: C:\Users\AliaksandrAladzyin\Documents\dq_platform_foundation
# Data dir: C:\Users\AliaksandrAladzyin\Documents\dq_platform_foundation\data\raw
# Materials exists: True
# Goods exists: True
